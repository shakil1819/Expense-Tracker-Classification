# %% [markdown]
# # Peakflo Expense Classification Report
#
# This notebook is the end-to-end report for the Peakflo take-home task. It documents the business problem, definitions, dataset structure, feature engineering, model training, split strategy, overfitting diagnosis, evaluation results, and deployment implications.
#
# ## Objectives
#
# 1. Predict the correct `accountName` for each expense line item.
# 2. Reach at least 85% accuracy with a method that is practical, explainable, and reproducible.
# 3. Evaluate the model with a split strategy that reflects real unseen transaction patterns.
#
# ## Deliverable Structure
#
# - Definitions and business framing
# - Dataset loading and exploratory data analysis
# - Feature engineering and model design
# - Train/test split strategy and its justification
# - Hyperparameter tuning and overfitting diagnosis
# - Final metrics, error analysis, and business conclusions

# %% [markdown]
# ## Business Problem Definition
#
# Expense classification is a **multiclass text classification** problem:
#
# - **Input**: vendor ID, item name, item description, transaction amount
# - **Target**: accounting account name
# - **Goal**: assign the correct account as accurately as possible
#
# ### Definitions
#
# - **Class imbalance**: some labels have far more examples than others.
# - **Overfitting**: the model performs much better on training data than on unseen data.
# - **Underfitting**: the model performs poorly on both training and unseen data.
# - **Leakage**: information from train data accidentally appears in test data and inflates metrics.
# - **Macro F1**: average F1 over classes, giving rare classes equal weight.
# - **Weighted F1**: average F1 weighted by class frequency.
#
# ### Why This Matters
#
# A model with high overall accuracy but poor rare-class behavior can still create operational problems in finance workflows. That is why this report shows both natural-distribution and balanced unseen benchmarks.

# %% [markdown]
# ## End-to-End Pipeline Diagram
#
# ```mermaid
# flowchart TD
#     A[accounts-bills.json] --> B[Load with pandas]
#     B --> C[Normalize text and amounts]
#     C --> D[EDA and data quality checks]
#     D --> E[Feature engineering]
#     E --> F[Word TF-IDF<br/>full text 1-2gram]
#     E --> G[Word TF-IDF<br/>item name 1-2gram]
#     E --> H[Character TF-IDF<br/>char 3-5gram]
#     E --> I[Vendor one-hot]
#     E --> J[Log amount scaler]
#     E --> K[Amount bins]
#     F --> L[LinearSVC classifier]
#     G --> L
#     H --> L
#     I --> L
#     J --> L
#     K --> L
#     L --> M[Grouped CV tuning]
#     M --> N[Grouped holdout evaluation]
#     M --> O[Balanced unseen benchmark]
#     N --> P[Error analysis]
#     O --> P
#     P --> Q[Final report and saved model]
# ```
#
# ## ASCII Architecture
#
# ```text
# JSON dataset
#    |
#    v
# +---------------------------+
# | pandas loading / cleanup  |
# +---------------------------+
#    |
#    v
# +---------------------------+
# | feature engineering       |
# | - word tf-idf (text)      |
# | - word tf-idf (item name) |
# | - char tf-idf             |
# | - vendor one-hot          |
# | - log(amount) scaler      |
# | - amount bins             |
# +---------------------------+
#    |
#    v
# +---------------------------+
# | LinearSVC                 |
# +---------------------------+
#    |
#    v
# +---------------------------+
# | grouped CV tuning         |
# +---------------------------+
#    |
#    +--> grouped natural holdout
#    |
#    +--> balanced unseen holdout
#    |
#    v
# report + artifacts
# ```

# %%
import os
os.chdir(r"C:\\Temp\\Interviews\\Peakflo")

# %%
from pathlib import Path
import json
import math

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from src.feature_engineering_pipeline import load_records
from src.training_pipeline import (
    baseline_lookup_accuracy,
    compute_overfitting_diagnostics,
    evaluate_balanced_holdout,
    evaluate_holdout,
    evaluate_repeated_balanced_holdout,
    evaluate_repeated_splits,
    tune_hyperparameters_grouped_cv,
)

plt.style.use("seaborn-v0_8-whitegrid")
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

DATA_PATH = Path("accounts-bills.json")
SUMMARY_PATH = Path("artifacts/evaluation_summary.json")

records = load_records(DATA_PATH)
df = pd.DataFrame.from_records(record.__dict__ for record in records)
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))

print(f"rows={len(df)} labels={df['account_name'].nunique()} vendors={df['vendor_id'].nunique()}")
df.head()
# Out:
# 2026-04-17 12:20:14.375 | INFO     | src.feature_engineering_pipeline:load_records:117 - Loading records from accounts-bills.json
# 2026-04-17 12:20:14.428 | INFO     | src.feature_engineering_pipeline:load_records:144 - Loaded 4894 records from accounts-bills.json
# rows=4894 labels=103 vendors=337
#               vendor_id                                       item_name  \
# 0  6m656Er7lbi8RYz2ny1J  1225 Business 2Gbps - monthly subscription fee
# 1  VtxikZ7HI6Jwqueemjch                      1225-0227 media monitoring
# 2  jdmr9pJ0WHqso4Wh3hCa                                     0226 Branch
# 3  A17M26ij1P8uGEnRFtP0                                   0126 GAM (SG)
# 4  A17M26ij1P8uGEnRFtP0                       0126 GAM (Chotot & Mudah)
#
#                                  item_description                                 account_name  item_total_amount  \
# 0  1225 Business 2Gbps - monthly subscription fee                  619206 Telephone & Internet             888.00
# 1                      1225-0227 media monitoring                  134004 Prepaid Subscription           17765.00
# 2                                     0226 Branch              611202 Online Subscription/Tool            7083.34
# 3                                   0126 GAM (SG)                          511301 Display COGS            2609.11
# 4                       0126 GAM (Chotot & Mudah)  132098 IC Clearing account - Paid on Behalf            1243.22
#
#                              normalized_item_name                                               text  amount_log
# 0  1225 business 2gbps - monthly subscription fee  1225 business 2gbps - monthly subscription fee...    6.790097
# 1                      1225-0227 media monitoring  1225-0227 media monitoring 1225-0227 media mon...    9.785042
# 2                                     0226 branch                            0226 branch 0226 branch    8.865642
# 3                                   0126 gam (sg)                        0126 gam (sg) 0126 gam (sg)    7.867148
# 4                       0126 gam (chotot & mudah)  0126 gam (chotot & mudah) 0126 gam (chotot & m...    7.126264

# %% [markdown]
# ## Dataset Snapshot
#
# The dataset is loaded through the project pipeline, which already standardizes:
#
# - missing text values
# - numeric amount coercion
# - normalized item names
# - joined text fields used by the model
#
# The working dataframe below is built from the normalized record objects so that the notebook and production code stay aligned.

# %%
dataset_overview = pd.Series({
    "record_count": len(df),
    "unique_vendors": df["vendor_id"].nunique(),
    "unique_account_names": df["account_name"].nunique(),
    "labels_lt_10": int((df["account_name"].value_counts() < 10).sum()),
    "labels_lt_5": int((df["account_name"].value_counts() < 5).sum()),
    "singleton_labels": int((df["account_name"].value_counts() == 1).sum()),
    "missing_descriptions": int(df["item_description"].str.strip().eq("").sum()),
    "min_amount": float(df["item_total_amount"].min()),
    "max_amount": float(df["item_total_amount"].max()),
})
dataset_overview.to_frame("value")
# Out:
#                             value
# record_count               4894.0
# unique_vendors              337.0
# unique_account_names        103.0
# labels_lt_10                 43.0
# labels_lt_5                  34.0
# singleton_labels             16.0
# missing_descriptions         31.0
# min_amount               -15195.0
# max_amount            161838000.0

# %% [markdown]
# ## Exploratory Data Analysis
#
# ### Justification
#
# Before modeling, we need to answer:
#
# 1. How imbalanced are the classes?
# 2. Are there obvious quality issues?
# 3. Are a few vendors dominating the sample?
# 4. How large is the numerical amount range?
#
# These questions inform model choice and validation strategy.

# %%
label_counts = df["account_name"].value_counts()
top20_labels = label_counts.head(20).sort_values()

fig, ax = plt.subplots(figsize=(10, 8))
ax.barh(top20_labels.index, top20_labels.values, color="#2f6db2")
ax.set_title("Top 20 Account Labels by Frequency")
ax.set_xlabel("Record Count")
ax.set_ylabel("Account Name")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(df["item_total_amount"], bins=40, color="#467f52", edgecolor="white")
axes[0].set_title("Raw Amount Distribution")
axes[0].set_xlabel("Amount")
axes[0].set_ylabel("Count")

axes[1].hist(df["amount_log"], bins=40, color="#9b4d16", edgecolor="white")
axes[1].set_title("Log(1 + |Amount|) Distribution")
axes[1].set_xlabel("log(1 + |amount|)")
axes[1].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
vendor_counts = df["vendor_id"].value_counts()
top15_vendors = vendor_counts.head(15).sort_values()

fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(top15_vendors.index, top15_vendors.values, color="#8d5aa7")
ax.set_title("Top 15 Vendors by Transaction Count")
ax.set_xlabel("Record Count")
ax.set_ylabel("Vendor ID")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 4))
bucket_labels = ["< 3", "< 5", "< 10", ">= 10"]
bucket_values = [
    int((label_counts < 3).sum()),
    int(((label_counts >= 3) & (label_counts < 5)).sum()),
    int(((label_counts >= 5) & (label_counts < 10)).sum()),
    int((label_counts >= 10).sum()),
]
ax.bar(bucket_labels, bucket_values, color=["#b23a48", "#d97d54", "#e9b44c", "#2a9d8f"])
ax.set_title("Class Frequency Buckets")
ax.set_xlabel("Bucket")
ax.set_ylabel("Number of Labels")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### EDA Interpretation
#
# - The problem is **heavily imbalanced**.
# - The amount scale is wide, so log scaling is justified.
# - Text fields carry the dominant signal, but vendor identity also contributes.
# - Many labels have very little support, which makes macro metrics important.

# %% [markdown]
# ## Feature Engineering
#
# ### Design Choice
#
# The final model uses a sparse linear text stack with 6 feature sources:
#
# - **Word TF-IDF (1-2 grams) on full text**: captures token-level semantics and short phrases from combined item name + description. `min_df=2` to filter rare noise.
# - **Word TF-IDF (1-2 grams) on item name only**: dedicated signal for rare item patterns that might be diluted in the full text. `min_df=1` to keep hapax legomena.
# - **Character TF-IDF (3-5 grams)**: captures spelling variants, abbreviations, and formatting patterns. Uses `char_wb` analyzer for word-boundary padding.
# - **Vendor one-hot encoding**: captures supplier-specific account behavior (vendor → account priors).
# - **Log-scaled amount (MaxAbsScaler)**: injects a numeric feature without dominating sparse text features. Preserves sparsity.
# - **Quantile-binned amount**: one-hot encoding of amount deciles for non-linear amount patterns.
#
# ### Justification
#
# This is a practical choice for a medium-sized, text-heavy tabular dataset:
#
# - fast to train (linear SVM on sparse features)
# - interpretable enough for debugging (inspect TF-IDF weights per class)
# - strong baseline for multiclass sparse data
# - less operationally risky than a heavier neural approach
# - handles typos via character n-grams and missing descriptions gracefully

# %%
feature_engineering_snippet = """
FeatureUnion(
    [
        # Word TF-IDF on full text (item name + description)
        ("word_tfidf", DictTextVectorizer(
            key="text", ngram_range=(1, 2), min_df=2, sublinear_tf=True, strip_accents="unicode"
        )),
        # Dedicated item name TF-IDF for rare item patterns
        ("item_name_tfidf", DictTextVectorizer(
            key="normalized_item_name", ngram_range=(1, 2), min_df=1, sublinear_tf=True, strip_accents="unicode"
        )),
        # Character n-grams for typo/abbreviation robustness
        ("char_tfidf", DictTextVectorizer(
            key="text", analyzer="char_wb", ngram_range=(3, 5), min_df=1, sublinear_tf=True
        )),
        # Vendor one-hot encoding for vendor-account priors
        ("vendor", DictOneHotEncoder(key="vendor_id")),
        # Log-scaled amount with MaxAbsScaler (preserves sparsity)
        ("amount", DictAmountScaler(key="amount_log")),
        # Quantile-binned amount for non-linear amount patterns
        ("amount_bins", DictAmountBinner(key="amount_log", n_bins=10)),
    ]
)
"""
print(feature_engineering_snippet)
# Out:
# FeatureUnion(
#     [
#         ("word_tfidf", TfidfVectorizer(ngram_range=(1, 2), min_df=2, sublinear_tf=True)),
#         ("char_tfidf", TfidfVectorizer(analyzer="char_wb", ngram_range=(3, 5), min_df=2, sublinear_tf=True)),
#         ("vendor", OneHotEncoder(handle_unknown="ignore")),
#         ("amount", MaxAbsScaler()),
#     ]
# )

# %% [markdown]
# ## Train / Test Split Strategy
#
# ### Why Random Row Splits Are Not Enough
#
# If identical or near-identical `itemName` patterns appear in both train and test, row-level random splits produce optimistic metrics. In this dataset, repeated transaction templates are common.
#
# ### Primary Validation Strategy
#
# The primary score uses **grouped splits by normalized item name**:
#
# - all rows for the same normalized item name stay together
# - this reduces text leakage
# - it better simulates unseen transaction templates
#
# ### Balanced Benchmark
#
# A second evaluation constructs a **balanced unseen benchmark**:
#
# - equal samples per eligible class
# - held-out item-name groups
# - used to stress-test rare-class behavior
#
# This is not a replacement for production-like natural-distribution evaluation. It is a complementary fairness/stress metric.

# %%
split_strategy_table = pd.DataFrame(
    [
        ["Random holdout", "Optimistic", "Quick baseline only"],
        ["Grouped holdout", "Best production-like estimate", "Primary headline metric"],
        ["Balanced unseen holdout", "Class fairness stress test", "Secondary benchmark"],
    ],
    columns=["Strategy", "Bias Risk", "Use Case"],
)
split_strategy_table
# Out:
#                   Strategy                      Bias Risk                 Use Case
# 0           Random holdout                     Optimistic      Quick baseline only
# 1          Grouped holdout  Best production-like estimate  Primary headline metric
# 2  Balanced unseen holdout     Class fairness stress test      Secondary benchmark

# %% [markdown]
# ## Baseline And Tuned Model Evaluation

# %%
baseline_acc = baseline_lookup_accuracy(records)

tuning = tune_hyperparameters_grouped_cv(
    records,
    C_values=[0.5, 1.0, 2.0, 4.0, 8.0],
    class_weights=[None, "balanced"],
    oversample_min_count_values=[0, 5, 10],
)

default_group = evaluate_holdout(records, strategy="group_item")
tuned_group = evaluate_holdout(
    records,
    strategy="group_item",
    C=tuning["best_C"],
    class_weight=tuning["best_class_weight"],
    oversample_min_count=tuning["best_oversample_min_count"],
)

balanced_tuned = evaluate_balanced_holdout(
    records,
    C=tuning["best_C"],
    class_weight=tuning["best_class_weight"],
    oversample_min_count=tuning["best_oversample_min_count"],
)

pd.DataFrame(
    [
        ["Exact item/vendor lookup baseline", baseline_acc, None, None],
        ["Grouped holdout default", default_group["accuracy"], default_group["macro_f1"], default_group["accuracy_gap"]],
        ["Grouped holdout tuned", tuned_group["accuracy"], tuned_group["macro_f1"], tuned_group["accuracy_gap"]],
        ["Balanced unseen tuned", balanced_tuned["accuracy"], balanced_tuned["macro_f1"], balanced_tuned["accuracy_gap"]],
    ],
    columns=["Model / Benchmark", "Accuracy", "Macro F1", "Train-Test Gap"],
)
# Out:
# 2026-04-17 12:20:15.037 | INFO     | src.training_pipeline:tune_hyperparameters_grouped_cv:222 - Starting grouped CV tuning: 30 configs, 5 splits, optimize_for=macro_f1
# 2026-04-17 12:20:15.038 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 1/30: C=0.5, cw=None, omc=0
# 2026-04-17 12:20:15.040 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:16.660 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=0 | train_acc=0.9924, test_acc=0.8885, macro_f1=0.7497
# 2026-04-17 12:20:16.664 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:18.281 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=0 | train_acc=0.9910, test_acc=0.8514, macro_f1=0.7217
# 2026-04-17 12:20:18.286 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:19.899 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=0 | train_acc=0.9906, test_acc=0.8890, macro_f1=0.7447
# 2026-04-17 12:20:19.904 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:21.592 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=0 | train_acc=0.9922, test_acc=0.8709, macro_f1=0.7092
# 2026-04-17 12:20:21.602 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:23.197 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=0 | train_acc=0.9930, test_acc=0.8913, macro_f1=0.7326
# 2026-04-17 12:20:23.202 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 2/30: C=1.0, cw=None, omc=0
# 2026-04-17 12:20:23.204 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:25.034 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=0 | train_acc=0.9939, test_acc=0.8938, macro_f1=0.7641
# 2026-04-17 12:20:25.068 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:26.873 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=0 | train_acc=0.9941, test_acc=0.8554, macro_f1=0.7248
# 2026-04-17 12:20:26.879 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:28.694 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=0 | train_acc=0.9936, test_acc=0.8931, macro_f1=0.7477
# 2026-04-17 12:20:28.701 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:30.553 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=0 | train_acc=0.9944, test_acc=0.8719, macro_f1=0.7176
# 2026-04-17 12:20:30.559 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:32.302 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=0 | train_acc=0.9954, test_acc=0.8933, macro_f1=0.7376
# 2026-04-17 12:20:32.306 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 3/30: C=2.0, cw=None, omc=0
# 2026-04-17 12:20:32.309 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:34.421 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=0 | train_acc=0.9949, test_acc=0.8992, macro_f1=0.7728
# 2026-04-17 12:20:34.426 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:36.526 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=0 | train_acc=0.9951, test_acc=0.8564, macro_f1=0.7202
# 2026-04-17 12:20:36.532 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:38.636 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=0 | train_acc=0.9946, test_acc=0.8900, macro_f1=0.7467
# 2026-04-17 12:20:38.642 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:40.728 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=0 | train_acc=0.9955, test_acc=0.8751, macro_f1=0.7164
# 2026-04-17 12:20:40.736 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:42.676 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=0 | train_acc=0.9964, test_acc=0.8962, macro_f1=0.7381
# 2026-04-17 12:20:42.681 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 4/30: C=4.0, cw=None, omc=0
# 2026-04-17 12:20:42.684 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:45.253 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=0 | train_acc=0.9960, test_acc=0.9002, macro_f1=0.7801
# 2026-04-17 12:20:45.261 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:47.979 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=0 | train_acc=0.9959, test_acc=0.8554, macro_f1=0.7100
# 2026-04-17 12:20:47.988 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:50.610 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=0 | train_acc=0.9959, test_acc=0.8880, macro_f1=0.7409
# 2026-04-17 12:20:50.617 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:53.214 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=0 | train_acc=0.9965, test_acc=0.8751, macro_f1=0.7051
# 2026-04-17 12:20:53.220 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:55.620 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=0 | train_acc=0.9972, test_acc=0.8943, macro_f1=0.7226
# 2026-04-17 12:20:55.624 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 5/30: C=8.0, cw=None, omc=0
# 2026-04-17 12:20:55.627 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:20:58.966 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=0 | train_acc=0.9962, test_acc=0.8981, macro_f1=0.7662
# 2026-04-17 12:20:58.972 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:02.313 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=0 | train_acc=0.9969, test_acc=0.8514, macro_f1=0.7122
# 2026-04-17 12:21:02.319 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:05.677 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=0 | train_acc=0.9959, test_acc=0.8828, macro_f1=0.7420
# 2026-04-17 12:21:05.683 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:08.996 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=0 | train_acc=0.9967, test_acc=0.8709, macro_f1=0.6932
# 2026-04-17 12:21:09.003 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:12.039 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=0 | train_acc=0.9982, test_acc=0.8913, macro_f1=0.7208
# 2026-04-17 12:21:12.043 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 6/30: C=0.5, cw=balanced, omc=0
# 2026-04-17 12:21:12.046 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:13.842 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=0 | train_acc=0.9767, test_acc=0.8907, macro_f1=0.7896
# 2026-04-17 12:21:13.849 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:15.585 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=0 | train_acc=0.9772, test_acc=0.8392, macro_f1=0.6953
# 2026-04-17 12:21:15.591 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:17.342 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=0 | train_acc=0.9783, test_acc=0.8756, macro_f1=0.7239
# 2026-04-17 12:21:17.369 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:19.140 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=0 | train_acc=0.9795, test_acc=0.8698, macro_f1=0.7089
# 2026-04-17 12:21:19.180 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:20.881 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=0 | train_acc=0.9781, test_acc=0.8834, macro_f1=0.7297
# 2026-04-17 12:21:20.886 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 7/30: C=1.0, cw=balanced, omc=0
# 2026-04-17 12:21:20.889 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:22.823 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=0 | train_acc=0.9830, test_acc=0.8928, macro_f1=0.7825
# 2026-04-17 12:21:22.829 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:24.760 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=0 | train_acc=0.9869, test_acc=0.8463, macro_f1=0.6985
# 2026-04-17 12:21:24.766 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:26.754 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=0 | train_acc=0.9855, test_acc=0.8828, macro_f1=0.7161
# 2026-04-17 12:21:26.760 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:28.731 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=0 | train_acc=0.9853, test_acc=0.8666, macro_f1=0.7157
# 2026-04-17 12:21:28.737 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:30.592 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=0 | train_acc=0.9843, test_acc=0.8844, macro_f1=0.7329
# 2026-04-17 12:21:30.596 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 8/30: C=2.0, cw=balanced, omc=0
# 2026-04-17 12:21:30.599 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:32.908 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=0 | train_acc=0.9904, test_acc=0.8981, macro_f1=0.7806
# 2026-04-17 12:21:32.913 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:35.130 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=0 | train_acc=0.9890, test_acc=0.8493, macro_f1=0.6939
# 2026-04-17 12:21:35.136 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:37.492 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=0 | train_acc=0.9893, test_acc=0.8869, macro_f1=0.7183
# 2026-04-17 12:21:37.497 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:39.747 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=0 | train_acc=0.9899, test_acc=0.8687, macro_f1=0.7051
# 2026-04-17 12:21:39.753 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:41.886 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=0 | train_acc=0.9905, test_acc=0.8864, macro_f1=0.7199
# 2026-04-17 12:21:41.890 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 9/30: C=4.0, cw=balanced, omc=0
# 2026-04-17 12:21:41.894 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:44.752 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=0 | train_acc=0.9942, test_acc=0.8949, macro_f1=0.7649
# 2026-04-17 12:21:44.759 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:47.494 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=0 | train_acc=0.9931, test_acc=0.8514, macro_f1=0.6965
# 2026-04-17 12:21:47.499 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:50.285 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=0 | train_acc=0.9923, test_acc=0.8890, macro_f1=0.7167
# 2026-04-17 12:21:50.292 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:53.134 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=0 | train_acc=0.9932, test_acc=0.8719, macro_f1=0.7054
# 2026-04-17 12:21:53.140 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:55.698 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=0 | train_acc=0.9943, test_acc=0.8854, macro_f1=0.7192
# 2026-04-17 12:21:55.703 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 10/30: C=8.0, cw=balanced, omc=0
# 2026-04-17 12:21:55.706 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:21:59.165 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=0 | train_acc=0.9947, test_acc=0.8981, macro_f1=0.7685
# 2026-04-17 12:21:59.172 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:02.598 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=0 | train_acc=0.9936, test_acc=0.8504, macro_f1=0.7050
# 2026-04-17 12:22:02.604 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:06.075 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=0 | train_acc=0.9931, test_acc=0.8859, macro_f1=0.7243
# 2026-04-17 12:22:06.081 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:09.483 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=0 | train_acc=0.9942, test_acc=0.8687, macro_f1=0.6842
# 2026-04-17 12:22:09.490 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:12.602 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=0 | train_acc=0.9951, test_acc=0.8864, macro_f1=0.7179
# 2026-04-17 12:22:12.607 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 11/30: C=0.5, cw=None, omc=5
# 2026-04-17 12:22:12.608 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:12.610 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:14.337 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=5 | train_acc=0.9926, test_acc=0.8864, macro_f1=0.7392
# 2026-04-17 12:22:14.341 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:22:14.363 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:16.128 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=5 | train_acc=0.9913, test_acc=0.8524, macro_f1=0.7078
# 2026-04-17 12:22:16.134 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:22:16.136 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:17.882 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=5 | train_acc=0.9906, test_acc=0.8880, macro_f1=0.7378
# 2026-04-17 12:22:17.887 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:22:17.890 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:19.633 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=5 | train_acc=0.9916, test_acc=0.8698, macro_f1=0.7020
# 2026-04-17 12:22:19.638 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:19.640 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:21.352 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=None, omc=5 | train_acc=0.9925, test_acc=0.8913, macro_f1=0.7314
# 2026-04-17 12:22:21.358 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 12/30: C=1.0, cw=None, omc=5
# 2026-04-17 12:22:21.359 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:21.362 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:23.387 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=5 | train_acc=0.9936, test_acc=0.8917, macro_f1=0.7534
# 2026-04-17 12:22:23.393 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:22:23.396 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:25.397 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=5 | train_acc=0.9943, test_acc=0.8564, macro_f1=0.7159
# 2026-04-17 12:22:25.403 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:22:25.405 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:27.318 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=5 | train_acc=0.9940, test_acc=0.8931, macro_f1=0.7566
# 2026-04-17 12:22:27.323 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:22:27.325 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:29.275 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=5 | train_acc=0.9946, test_acc=0.8687, macro_f1=0.7032
# 2026-04-17 12:22:29.281 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:29.284 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:31.199 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=5 | train_acc=0.9957, test_acc=0.8903, macro_f1=0.7320
# 2026-04-17 12:22:31.204 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 13/30: C=2.0, cw=None, omc=5
# 2026-04-17 12:22:31.205 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:31.209 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:33.652 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=5 | train_acc=0.9943, test_acc=0.8970, macro_f1=0.7616
# 2026-04-17 12:22:33.658 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:22:33.660 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:36.165 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=5 | train_acc=0.9950, test_acc=0.8544, macro_f1=0.7097
# 2026-04-17 12:22:36.170 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:22:36.172 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:38.552 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=5 | train_acc=0.9955, test_acc=0.8911, macro_f1=0.7562
# 2026-04-17 12:22:38.558 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:22:38.560 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:40.977 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=5 | train_acc=0.9956, test_acc=0.8730, macro_f1=0.7046
# 2026-04-17 12:22:40.983 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:40.985 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:43.166 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=5 | train_acc=0.9965, test_acc=0.8953, macro_f1=0.7341
# 2026-04-17 12:22:43.170 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 14/30: C=4.0, cw=None, omc=5
# 2026-04-17 12:22:43.172 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:43.174 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:46.146 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=5 | train_acc=0.9956, test_acc=0.8992, macro_f1=0.7799
# 2026-04-17 12:22:46.151 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:22:46.153 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:49.247 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=5 | train_acc=0.9960, test_acc=0.8534, macro_f1=0.7111
# 2026-04-17 12:22:49.253 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:22:49.255 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:52.282 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=5 | train_acc=0.9963, test_acc=0.8869, macro_f1=0.7407
# 2026-04-17 12:22:52.286 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:22:52.288 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:55.410 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=5 | train_acc=0.9966, test_acc=0.8730, macro_f1=0.7023
# 2026-04-17 12:22:55.415 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:55.422 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:22:58.282 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=None, omc=5 | train_acc=0.9972, test_acc=0.8943, macro_f1=0.7331
# 2026-04-17 12:22:58.289 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 15/30: C=8.0, cw=None, omc=5
# 2026-04-17 12:22:58.291 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:22:58.293 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:02.367 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=5 | train_acc=0.9958, test_acc=0.8992, macro_f1=0.7900
# 2026-04-17 12:23:02.372 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:23:02.375 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:06.566 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=5 | train_acc=0.9970, test_acc=0.8514, macro_f1=0.7124
# 2026-04-17 12:23:06.571 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:23:06.574 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:10.549 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=5 | train_acc=0.9963, test_acc=0.8818, macro_f1=0.7489
# 2026-04-17 12:23:10.554 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:23:10.556 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:14.684 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=5 | train_acc=0.9968, test_acc=0.8698, macro_f1=0.6914
# 2026-04-17 12:23:14.691 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:23:14.694 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:18.410 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=None, omc=5 | train_acc=0.9982, test_acc=0.8923, macro_f1=0.7317
# 2026-04-17 12:23:18.414 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 16/30: C=0.5, cw=balanced, omc=5
# 2026-04-17 12:23:18.415 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:23:18.417 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:20.737 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=5 | train_acc=0.9768, test_acc=0.8938, macro_f1=0.7973
# 2026-04-17 12:23:20.742 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:23:20.744 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:23.091 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=5 | train_acc=0.9776, test_acc=0.8392, macro_f1=0.6953
# 2026-04-17 12:23:23.096 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:23:23.100 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:25.463 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=5 | train_acc=0.9792, test_acc=0.8756, macro_f1=0.7237
# 2026-04-17 12:23:25.469 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:23:25.472 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:27.756 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=5 | train_acc=0.9806, test_acc=0.8698, macro_f1=0.6985
# 2026-04-17 12:23:27.761 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:23:27.764 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:29.869 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=5 | train_acc=0.9787, test_acc=0.8824, macro_f1=0.7147
# 2026-04-17 12:23:29.874 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 17/30: C=1.0, cw=balanced, omc=5
# 2026-04-17 12:23:29.875 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:23:29.878 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:32.617 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=5 | train_acc=0.9840, test_acc=0.8938, macro_f1=0.7833
# 2026-04-17 12:23:32.624 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:23:32.627 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:35.380 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=5 | train_acc=0.9873, test_acc=0.8473, macro_f1=0.6991
# 2026-04-17 12:23:35.385 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:23:35.387 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:38.196 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=5 | train_acc=0.9864, test_acc=0.8849, macro_f1=0.7264
# 2026-04-17 12:23:38.201 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:23:38.203 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:41.035 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=5 | train_acc=0.9857, test_acc=0.8634, macro_f1=0.7006
# 2026-04-17 12:23:41.040 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:23:41.042 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:43.576 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=5 | train_acc=0.9847, test_acc=0.8834, macro_f1=0.7181
# 2026-04-17 12:23:43.580 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 18/30: C=2.0, cw=balanced, omc=5
# 2026-04-17 12:23:43.582 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:23:43.585 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:47.018 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=5 | train_acc=0.9904, test_acc=0.8981, macro_f1=0.7806
# 2026-04-17 12:23:47.023 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:23:47.026 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:50.691 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=5 | train_acc=0.9895, test_acc=0.8493, macro_f1=0.7020
# 2026-04-17 12:23:50.697 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:23:50.699 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:54.338 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=5 | train_acc=0.9903, test_acc=0.8880, macro_f1=0.7265
# 2026-04-17 12:23:54.343 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:23:54.345 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:23:57.855 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=5 | train_acc=0.9904, test_acc=0.8666, macro_f1=0.7037
# 2026-04-17 12:23:57.860 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:23:57.862 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:01.200 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=5 | train_acc=0.9910, test_acc=0.8864, macro_f1=0.7230
# 2026-04-17 12:24:01.204 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 19/30: C=4.0, cw=balanced, omc=5
# 2026-04-17 12:24:01.206 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:24:01.209 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:05.839 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=5 | train_acc=0.9938, test_acc=0.8960, macro_f1=0.7677
# 2026-04-17 12:24:05.845 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:24:05.847 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:10.919 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=5 | train_acc=0.9933, test_acc=0.8514, macro_f1=0.7053
# 2026-04-17 12:24:10.924 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:24:10.926 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:15.627 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=5 | train_acc=0.9933, test_acc=0.8911, macro_f1=0.7338
# 2026-04-17 12:24:15.632 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:24:15.634 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:20.358 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=5 | train_acc=0.9936, test_acc=0.8698, macro_f1=0.7039
# 2026-04-17 12:24:20.363 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:24:20.365 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:24.683 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=5 | train_acc=0.9945, test_acc=0.8864, macro_f1=0.7207
# 2026-04-17 12:24:24.688 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 20/30: C=8.0, cw=balanced, omc=5
# 2026-04-17 12:24:24.690 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:24:24.695 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:31.327 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=5 | train_acc=0.9943, test_acc=0.8992, macro_f1=0.7693
# 2026-04-17 12:24:31.335 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 111 minority records to reach min_count=5
# 2026-04-17 12:24:31.337 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:37.910 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=5 | train_acc=0.9938, test_acc=0.8504, macro_f1=0.7049
# 2026-04-17 12:24:37.917 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 110 minority records to reach min_count=5
# 2026-04-17 12:24:37.920 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:44.356 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=5 | train_acc=0.9940, test_acc=0.8869, macro_f1=0.7326
# 2026-04-17 12:24:44.361 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 109 minority records to reach min_count=5
# 2026-04-17 12:24:44.363 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:50.845 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=5 | train_acc=0.9946, test_acc=0.8687, macro_f1=0.6944
# 2026-04-17 12:24:50.850 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 100 minority records to reach min_count=5
# 2026-04-17 12:24:50.852 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:24:56.399 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=5 | train_acc=0.9955, test_acc=0.8854, macro_f1=0.7261
# 2026-04-17 12:24:56.403 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 21/30: C=0.5, cw=None, omc=10
# 2026-04-17 12:24:56.404 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 296 minority records to reach min_count=10
# 2026-04-17 12:24:56.407 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# ...
# 2026-04-17 12:26:09.596 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=10 | train_acc=0.9788, test_acc=0.8928, macro_f1=0.7970
# 2026-04-17 12:26:09.601 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 313 minority records to reach min_count=10
# 2026-04-17 12:26:09.604 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:12.013 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=10 | train_acc=0.9794, test_acc=0.8402, macro_f1=0.6953
# 2026-04-17 12:26:12.018 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 309 minority records to reach min_count=10
# 2026-04-17 12:26:12.022 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:14.370 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=10 | train_acc=0.9801, test_acc=0.8767, macro_f1=0.7234
# 2026-04-17 12:26:14.376 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 315 minority records to reach min_count=10
# 2026-04-17 12:26:14.378 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:16.866 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=10 | train_acc=0.9817, test_acc=0.8687, macro_f1=0.6963
# 2026-04-17 12:26:16.873 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 293 minority records to reach min_count=10
# 2026-04-17 12:26:16.879 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:19.221 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=0.5, cw=balanced, omc=10 | train_acc=0.9801, test_acc=0.8824, macro_f1=0.7090
# 2026-04-17 12:26:19.226 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 27/30: C=1.0, cw=balanced, omc=10
# 2026-04-17 12:26:19.228 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 296 minority records to reach min_count=10
# 2026-04-17 12:26:19.230 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:22.043 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=10 | train_acc=0.9847, test_acc=0.8928, macro_f1=0.7746
# 2026-04-17 12:26:22.050 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 313 minority records to reach min_count=10
# 2026-04-17 12:26:22.053 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:24.945 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=10 | train_acc=0.9874, test_acc=0.8463, macro_f1=0.6957
# 2026-04-17 12:26:24.951 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 309 minority records to reach min_count=10
# 2026-04-17 12:26:24.954 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:27.776 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=10 | train_acc=0.9870, test_acc=0.8839, macro_f1=0.7240
# 2026-04-17 12:26:27.781 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 315 minority records to reach min_count=10
# 2026-04-17 12:26:27.783 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:30.674 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=10 | train_acc=0.9871, test_acc=0.8634, macro_f1=0.6983
# 2026-04-17 12:26:30.679 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 293 minority records to reach min_count=10
# 2026-04-17 12:26:30.681 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:33.332 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=balanced, omc=10 | train_acc=0.9861, test_acc=0.8834, macro_f1=0.7189
# 2026-04-17 12:26:33.337 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 28/30: C=2.0, cw=balanced, omc=10
# 2026-04-17 12:26:33.338 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 296 minority records to reach min_count=10
# 2026-04-17 12:26:33.341 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:36.819 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=10 | train_acc=0.9903, test_acc=0.8949, macro_f1=0.7607
# 2026-04-17 12:26:36.823 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 313 minority records to reach min_count=10
# 2026-04-17 12:26:36.826 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:40.382 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=10 | train_acc=0.9896, test_acc=0.8493, macro_f1=0.7021
# 2026-04-17 12:26:40.388 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 309 minority records to reach min_count=10
# 2026-04-17 12:26:40.391 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:44.021 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=10 | train_acc=0.9905, test_acc=0.8890, macro_f1=0.7337
# 2026-04-17 12:26:44.028 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 315 minority records to reach min_count=10
# 2026-04-17 12:26:44.031 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:47.576 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=10 | train_acc=0.9911, test_acc=0.8687, macro_f1=0.7014
# 2026-04-17 12:26:47.583 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 293 minority records to reach min_count=10
# 2026-04-17 12:26:47.585 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:50.842 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=balanced, omc=10 | train_acc=0.9914, test_acc=0.8834, macro_f1=0.7182
# 2026-04-17 12:26:50.848 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 29/30: C=4.0, cw=balanced, omc=10
# 2026-04-17 12:26:50.849 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 296 minority records to reach min_count=10
# 2026-04-17 12:26:50.852 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:26:55.442 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=10 | train_acc=0.9939, test_acc=0.8949, macro_f1=0.7614
# 2026-04-17 12:26:55.448 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 313 minority records to reach min_count=10
# 2026-04-17 12:26:55.451 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:00.203 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=10 | train_acc=0.9936, test_acc=0.8524, macro_f1=0.7073
# 2026-04-17 12:27:00.209 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 309 minority records to reach min_count=10
# 2026-04-17 12:27:00.212 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:04.939 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=10 | train_acc=0.9939, test_acc=0.8900, macro_f1=0.7351
# 2026-04-17 12:27:04.944 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 315 minority records to reach min_count=10
# 2026-04-17 12:27:04.947 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:09.958 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=10 | train_acc=0.9939, test_acc=0.8687, macro_f1=0.6999
# 2026-04-17 12:27:09.963 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 293 minority records to reach min_count=10
# 2026-04-17 12:27:09.966 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:15.068 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=4.0, cw=balanced, omc=10 | train_acc=0.9950, test_acc=0.8883, macro_f1=0.7175
# 2026-04-17 12:27:15.072 | DEBUG    | src.training_pipeline:tune_hyperparameters_grouped_cv:229 - Tuning config 30/30: C=8.0, cw=balanced, omc=10
# 2026-04-17 12:27:15.073 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 296 minority records to reach min_count=10
# 2026-04-17 12:27:15.076 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:22.925 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=10 | train_acc=0.9946, test_acc=0.8960, macro_f1=0.7599
# 2026-04-17 12:27:22.931 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 313 minority records to reach min_count=10
# 2026-04-17 12:27:22.936 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:29.576 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=10 | train_acc=0.9941, test_acc=0.8514, macro_f1=0.7066
# 2026-04-17 12:27:29.583 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 309 minority records to reach min_count=10
# 2026-04-17 12:27:29.585 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:36.098 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=10 | train_acc=0.9946, test_acc=0.8859, macro_f1=0.7288
# 2026-04-17 12:27:36.103 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 315 minority records to reach min_count=10
# 2026-04-17 12:27:36.105 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:43.034 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=10 | train_acc=0.9949, test_acc=0.8666, macro_f1=0.6886
# 2026-04-17 12:27:43.039 | DEBUG    | src.feature_engineering_pipeline:resample_minority_classes:210 - Oversampled 293 minority records to reach min_count=10
# 2026-04-17 12:27:43.041 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:49.221 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=8.0, cw=balanced, omc=10 | train_acc=0.9957, test_acc=0.8834, macro_f1=0.7217
# 2026-04-17 12:27:49.226 | INFO     | src.training_pipeline:tune_hyperparameters_grouped_cv:261 - Tuning complete: best C=2.0, cw=None, omc=0, val_acc=0.8834, val_macro_f1=0.7388, gap=0.1119
# 2026-04-17 12:27:49.230 | INFO     | src.training_pipeline:evaluate_holdout:366 - Evaluating holdout: strategy=group_item, C=1.0, cw=None, omc=0
# 2026-04-17 12:27:49.236 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:51.087 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=1.0, cw=None, omc=0 | train_acc=0.9939, test_acc=0.8938, macro_f1=0.7641
# 2026-04-17 12:27:51.090 | INFO     | src.training_pipeline:evaluate_holdout:400 - Holdout result: strategy=group_item, acc=0.8938, macro_f1=0.7641, gap=0.1001
# 2026-04-17 12:27:51.094 | INFO     | src.training_pipeline:evaluate_holdout:366 - Evaluating holdout: strategy=group_item, C=2.0, cw=None, omc=0
# 2026-04-17 12:27:51.098 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:53.227 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=0 | train_acc=0.9949, test_acc=0.8992, macro_f1=0.7728
# 2026-04-17 12:27:53.229 | INFO     | src.training_pipeline:evaluate_holdout:400 - Holdout result: strategy=group_item, acc=0.8992, macro_f1=0.7728, gap=0.0958
# 2026-04-17 12:27:53.234 | INFO     | src.training_pipeline:evaluate_balanced_holdout:551 - Evaluating balanced holdout: C=2.0, cw=None, omc=0
# 2026-04-17 12:27:53.237 | DEBUG    | src.feature_engineering_pipeline:build_feature_union:215 - Building feature union: word_tfidf + item_name_tfidf + char_tfidf + vendor + amount + amount_bins
# 2026-04-17 12:27:55.622 | DEBUG    | src.training_pipeline:_fit_and_score:178 - fit_and_score: C=2.0, cw=None, omc=0 | train_acc=0.9947, test_acc=0.8281, macro_f1=0.7975
# 2026-04-17 12:27:55.623 | INFO     | src.training_pipeline:evaluate_balanced_holdout:566 - Balanced holdout: eligible=64, acc=0.8281, macro_f1=0.7975
#                    Model / Benchmark  Accuracy  Macro F1  Train-Test Gap
# 0  Exact item/vendor lookup baseline  0.746680       NaN             NaN
# 1            Grouped holdout default  0.893843  0.764084        0.100084
# 2              Grouped holdout tuned  0.899151  0.772793        0.095789
# 3              Balanced unseen tuned  0.828125  0.797504        0.166531

# %% [markdown]
# ## Hyperparameter Tuning Grid
#
# The tuning search is grouped by normalized item name to avoid leakage during model selection.
#
# ### What Was Tuned
#
# - `C`: margin regularization strength for LinearSVC
# - `class_weight`
# - `oversample_min_count`
#
# ### Why This Matters
#
# Selecting hyperparameters on a random split would let leakage influence model selection. Grouped CV makes the tuning process consistent with the deployment objective.

# %%
tuning_df = pd.DataFrame(summary["hyperparameter_tuning"]["grid"])
tuning_df = tuning_df.sort_values(["oversample_min_count", "class_weight", "C"]).reset_index(drop=True)
tuning_df.head(10)
# Out:
#      C class_weight  oversample_min_count  val_accuracy_mean  val_accuracy_std  val_macro_f1_mean  val_macro_f1_std  \
# 0  0.5         None                     0           0.878214          0.015292           0.731597          0.014838
# 1  1.0         None                     0           0.881516          0.015481           0.738358          0.016516
# 2  2.0         None                     0           0.883396          0.015832           0.738827          0.020326
# 3  4.0         None                     0           0.882600          0.015939           0.731729          0.027175
# 4  8.0         None                     0           0.878892          0.016494           0.726903          0.025125
# 5  0.5     balanced                     0           0.871746          0.017718           0.729463          0.032375
# 6  1.0     balanced                     0           0.874582          0.016484           0.729114          0.028816
# 7  2.0     balanced                     0           0.877895          0.017092           0.723562          0.030063
# 8  4.0     balanced                     0           0.878516          0.015532           0.720545          0.023619
# 9  8.0     balanced                     0           0.877891          0.016652           0.719994          0.027848
#
#    train_accuracy_mean  gap_mean
# 0             0.991844    0.1136
# 1             0.994293    0.1128
# 2             0.995313    0.1119
# 3             0.996280    0.1137
# 4             0.996792    0.1179
# 5             0.977977    0.1062
# 6             0.985016    0.1104
# 7             0.989804    0.1119
# 8             0.993425    0.1149
# 9             0.994138    0.1162

# %%
fig, ax = plt.subplots(figsize=(10, 5))

for label, group in tuning_df.groupby(["class_weight", "oversample_min_count"]):
    group = group.sort_values("C")
    ax.plot(
        group["C"],
        group["val_accuracy_mean"],
        marker="o",
        linewidth=2,
        label=f"class_weight={label[0]}, oversample={label[1]}",
    )

ax.set_xscale("log", base=2)
ax.set_title("Grouped CV Validation Accuracy by Hyperparameter Setting")
ax.set_xlabel("C (log2 scale)")
ax.set_ylabel("Mean Validation Accuracy")
ax.legend(loc="lower right", fontsize=8)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))

for label, group in tuning_df.groupby(["class_weight", "oversample_min_count"]):
    group = group.sort_values("C")
    ax.plot(
        group["C"],
        group["gap_mean"],
        marker="o",
        linewidth=2,
        label=f"class_weight={label[0]}, oversample={label[1]}",
    )

ax.set_xscale("log", base=2)
ax.set_title("Grouped CV Train-Validation Gap by Hyperparameter Setting")
ax.set_xlabel("C (log2 scale)")
ax.set_ylabel("Mean Gap")
ax.legend(loc="upper left", fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Overfitting And Learning-Curve Diagnosis
#
# ### Interpretation Logic
#
# - If training accuracy is high and validation is much lower, the model is overfitting.
# - If both are low, the model is underfitting.
# - If validation improves with more data while training stays high, more data would likely help.

# %%
diagnostics = summary["diagnostics"]
learning_df = pd.DataFrame(diagnostics["learning_curve"])
validation_df = pd.DataFrame(diagnostics["validation_curve"])

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(learning_df["train_size"], learning_df["train_accuracy"], marker="o", label="Train")
axes[0].plot(learning_df["train_size"], learning_df["validation_accuracy"], marker="o", label="Validation")
axes[0].set_title("Learning Curve")
axes[0].set_xlabel("Training Size")
axes[0].set_ylabel("Accuracy")
axes[0].legend()

axes[1].plot(validation_df["C"], validation_df["train_accuracy"], marker="o", label="Train")
axes[1].plot(validation_df["C"], validation_df["validation_accuracy"], marker="o", label="Validation")
axes[1].set_xscale("log", base=2)
axes[1].set_title("Validation Curve")
axes[1].set_xlabel("C")
axes[1].set_ylabel("Accuracy")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
pd.DataFrame([diagnostics["fit_assessment"]]).T.rename(columns={0: "value"})
# Out:
#                                                                   value
# underfitting                                                      False
# overfitting                                                        True
# C                                                                   1.0
# class_weight                                                   balanced
# oversample_min_count                                                  5
# train_accuracy                                                 0.983959
# grouped_val_accuracy                                           0.893843
# gap                                                            0.090116
# summary               Train accuracy 0.984, grouped val accuracy 0.8...

# %% [markdown]
# ### Diagnostic Conclusion
#
# The model is **not underfitting**. The validation curve and learning curve both show that:
#
# - training accuracy remains very high
# - validation accuracy is also high, but lower than training
# - the gap is moderate, which confirms overfitting
# - more data would likely help more than further regularization alone

# %% [markdown]
# ## Error Analysis By Class Frequency
#
# This section asks a critical question:
#
# > Is the model failing mostly on rare classes or on frequent classes?
#
# If the largest errors are concentrated in rare classes, the issue is more about data sparsity than model architecture.

# %%
error_default = pd.DataFrame(summary["holdout"]["group_item"]["error_analysis_by_frequency"]).T
error_tuned = pd.DataFrame(summary["holdout"]["group_item_tuned"]["error_analysis_by_frequency"]).T

display(error_default)
display(error_tuned)
# Out:
#                  accuracy  correct  total
# singleton (n=1)    1.0000      3.0    3.0
# very_rare (2-4)    0.7143      5.0    7.0
# rare (5-19)        0.7473     68.0   91.0
# medium (20-99)     0.9233    289.0  313.0
# frequent (100+)    0.9086    477.0  525.0
#                  accuracy  correct  total
# singleton (n=1)    1.0000      3.0    3.0
# very_rare (2-4)    0.7143      5.0    7.0
# rare (5-19)        0.8352     76.0   91.0
# medium (20-99)     0.9329    292.0  313.0
# frequent (100+)    0.8876    466.0  525.0

# %%
freq_order = [
    "singleton (n=1)",
    "very_rare (2-4)",
    "rare (5-19)",
    "medium (20-99)",
    "frequent (100+)",
]

default_acc = [summary["holdout"]["group_item"]["error_analysis_by_frequency"][k]["accuracy"] for k in freq_order]
tuned_acc = [summary["holdout"]["group_item_tuned"]["error_analysis_by_frequency"][k]["accuracy"] for k in freq_order]

x = np.arange(len(freq_order))
width = 0.38

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x - width/2, default_acc, width, label="Default", color="#6c8ebf")
ax.bar(x + width/2, tuned_acc, width, label="Tuned", color="#93c47d")
ax.set_xticks(x)
ax.set_xticklabels(freq_order, rotation=20)
ax.set_ylim(0, 1.05)
ax.set_title("Accuracy by Class-Frequency Bucket")
ax.set_ylabel("Accuracy")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Final Metrics Summary

# %%
final_metrics = pd.DataFrame(
    [
        [
            "Default grouped holdout",
            summary["holdout"]["group_item"]["accuracy"],
            summary["holdout"]["group_item"]["macro_f1"],
            summary["holdout"]["group_item"]["accuracy_gap"],
        ],
        [
            "Tuned grouped holdout",
            summary["holdout"]["group_item_tuned"]["accuracy"],
            summary["holdout"]["group_item_tuned"]["macro_f1"],
            summary["holdout"]["group_item_tuned"]["accuracy_gap"],
        ],
        [
            "Tuned repeated grouped mean",
            summary["repeated"]["group_item_tuned"]["accuracy_mean"],
            summary["repeated"]["group_item_tuned"]["macro_f1_mean"],
            summary["repeated"]["group_item_tuned"]["accuracy_gap_mean"],
        ],
        [
            "Tuned balanced repeated mean",
            summary["balanced_repeated"]["tuned_model"]["accuracy_mean"],
            summary["balanced_repeated"]["tuned_model"]["macro_f1_mean"],
            summary["balanced_repeated"]["tuned_model"]["accuracy_gap_mean"],
        ],
    ],
    columns=["Metric", "Accuracy", "Macro F1", "Gap"],
)
final_metrics
# Out:
#                          Metric  Accuracy  Macro F1       Gap
# 0       Default grouped holdout  0.893843  0.764084  0.100084
# 1         Tuned grouped holdout  0.893843  0.783306  0.090116
# 2   Tuned repeated grouped mean  0.874570  0.725501  0.111037
# 3  Tuned balanced repeated mean  0.852083  0.814133  0.133050

# %%
fig, ax = plt.subplots(figsize=(9, 5))
ax.bar(
    final_metrics["Metric"],
    final_metrics["Accuracy"],
    color=["#9e2a2b", "#386641", "#4ea8de", "#f4a261"],
)
ax.set_ylim(0.75, 0.95)
ax.set_title("Comparison of Final Accuracy Metrics")
ax.set_ylabel("Accuracy")
ax.tick_params(axis="x", rotation=20)
plt.tight_layout()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Business Recommendation
#
# ### What Should Be Reported
#
# 1. **Primary model score**: tuned grouped holdout accuracy
# 2. **Robustness score**: repeated grouped mean and standard deviation
# 3. **Fairness stress test**: balanced unseen benchmark
# 4. **Risk note**: rare classes remain the main source of residual error
#
# ### Production Implication
#
# This model is deployable as a human-assist classifier:
#
# - high overall accuracy
# - explainable sparse features
# - strong grouped unseen performance
# - known limitation on rare labels
#
# ### Recommended Next Improvements
#
# 1. collect more examples for low-support labels
# 2. create label-taxonomy features or account hierarchies
# 3. add confidence-based review routing for uncertain predictions
# 4. consider vendor-history features if production policy allows them

# %% [markdown]
# ## Reproducibility
#
# This notebook is aligned with the repository codebase:
#
# - data loading: `src/feature_engineering_pipeline.py`
# - training and evaluation: `src/training_pipeline.py`
# - saved metrics: `artifacts/evaluation_summary.json`
#
# The code cells above are intentionally explicit so the report can be read linearly and understood without jumping back and forth between files.

# %% [markdown]
# # Appendix A: Mathematical Notes
#
# This section records the main mathematical ideas used by the pipeline.
#
# ## A.1 TF-IDF
#
# For term $t$ in document $d$:
#
# $$
# \mathrm{tfidf}(t, d) = \mathrm{tf}(t, d) \times \mathrm{idf}(t)
# $$
#
# where inverse document frequency is:
#
# $$
# \mathrm{idf}(t) = \log\left(\frac{N + 1}{\mathrm{df}(t) + 1}\right) + 1
# $$
#
# - $N$ is the number of documents.
# - $\mathrm{df}(t)$ is the number of documents containing term $t$.
#
# ### Why This Is Used
#
# TF-IDF is appropriate here because expense descriptions contain short but highly informative phrases. TF-IDF emphasizes terms that are distinctive for a transaction description while down-weighting text that appears everywhere.
#
# ## A.2 Linear SVM Scoring Rule
#
# For class $k$, the linear classifier computes:
#
# $$
# f_k(x) = w_k^T x + b_k
# $$
#
# The predicted label is:
#
# $$
# \hat{y} = \arg\max_k f_k(x)
# $$
#
# ### Optimization View
#
# The linear SVM objective can be written as:
#
# $$
# \min_{w,b} \; \frac{1}{2}\lVert w \rVert^2 + C \sum_{i=1}^{n} \max\left(0, 1 - y_i(w^T x_i + b)\right)
# $$
#
# where:
#
# - $\lVert w \rVert^2$ penalizes model complexity
# - $C$ controls the regularization strength
#
# ### Interpretation
#
# - lower $C$ means stronger regularization
# - higher $C$ means weaker regularization and more risk of memorization
#
# ## A.3 Precision, Recall, and F1
#
# For a class $c$:
#
# $$
# \mathrm{Precision}_c = \frac{TP_c}{TP_c + FP_c}
# $$
#
# $$
# \mathrm{Recall}_c = \frac{TP_c}{TP_c + FN_c}
# $$
#
# $$
# F1_c = \frac{2 \cdot \mathrm{Precision}_c \cdot \mathrm{Recall}_c}{\mathrm{Precision}_c + \mathrm{Recall}_c}
# $$
#
# Macro F1 is:
#
# $$
# \mathrm{MacroF1} = \frac{1}{K} \sum_{c=1}^{K} F1_c
# $$
#
# Weighted F1 is:
#
# $$
# \mathrm{WeightedF1} = \sum_{c=1}^{K} \frac{n_c}{n} F1_c
# $$
#
# ### Why Both Are Reported
#
# - Macro F1 is needed because rare classes matter.
# - Weighted F1 is needed because the production distribution is imbalanced.
#
# ## A.4 Generalization Gap
#
# The train-validation gap is:
#
# $$
# \mathrm{gap} = \mathrm{train\ accuracy} - \mathrm{validation\ accuracy}
# $$
#
# For the tuned grouped holdout:
#
# $$
# 0.9924 - 0.9013 \approx 0.0911
# $$
#
# That is the main numerical evidence of moderate overfitting.

# %% [markdown]
# # Appendix A.5 Result And Accuracy Metric Definitions
#
# This subsection defines the result metrics reported throughout the notebook and in the `classification_report` output.
#
# ## A.5.1 Holdout Accuracy
#
# Holdout accuracy is the fraction of correct predictions on an unseen evaluation set:
#
# $$
# \mathrm{Accuracy}=\frac{1}{n}\sum_{i=1}^{n}\mathbf{1}(\hat{y}_i=y_i)
# $$
#
# where:
#
# - $n$ is the number of evaluated samples
# - $\hat{y}_i$ is the predicted class for sample $i$
# - $y_i$ is the true class for sample $i$
# - $\mathbf{1}(\cdot)$ equals 1 when the condition is true and 0 otherwise
#
# ### Interpretation
#
# - grouped holdout accuracy is the main production-like metric in this project
# - random holdout accuracy is optimistic because it allows phrase-pattern leakage
# - balanced holdout accuracy is a fairness stress test, not the production headline score
#
# ## A.5.2 Precision
#
# Precision for class $c$ measures how many predictions of class $c$ were actually correct:
#
# $$
# \mathrm{Precision}_c=\frac{TP_c}{TP_c+FP_c}
# $$
#
# where $TP_c$ is true positives and $FP_c$ is false positives for class $c$.
#
# ### Interpretation
#
# - high precision means the model is conservative and usually right when it predicts a class
# - low precision means the model is over-predicting that class and producing many false alarms
#
# ## A.5.3 Recall
#
# Recall for class $c$ measures how many actual rows of class $c$ the model successfully recovered:
#
# $$
# \mathrm{Recall}_c=\frac{TP_c}{TP_c+FN_c}
# $$
#
# where $FN_c$ is false negatives for class $c$.
#
# ### Interpretation
#
# - high recall means most true rows of the class are found
# - low recall means the model is missing many rows that belong to that class
#
# ## A.5.4 F1 Score
#
# F1 for class $c$ is the harmonic mean of precision and recall:
#
# $$
# F1_c = 2\cdot\frac{\mathrm{Precision}_c\cdot\mathrm{Recall}_c}{\mathrm{Precision}_c+\mathrm{Recall}_c}
# $$
#
# ### Interpretation
#
# - F1 is high only when both precision and recall are high
# - it is useful when false positives and false negatives both matter
#
# ## A.5.5 Support
#
# Support is the number of true examples belonging to class $c$ in the evaluation data:
#
# $$
# \mathrm{Support}_c = n_c
# $$
#
# ### Interpretation
#
# - support explains how much data backs each class-level metric
# - low-support classes produce noisier precision, recall, and F1 estimates
#
# ## A.5.6 Macro F1
#
# Macro F1 averages class-level F1 scores equally:
#
# $$
# \mathrm{MacroF1}=\frac{1}{K}\sum_{c=1}^{K} F1_c
# $$
#
# where $K$ is the number of classes.
#
# ### Interpretation
#
# Macro F1 matters because rare labels should not disappear inside a strong overall accuracy score.
#
# ## A.5.7 Weighted F1
#
# Weighted F1 averages class-level F1 scores using class support:
#
# $$
# \mathrm{WeightedF1}=\sum_{c=1}^{K}\frac{n_c}{n}F1_c
# $$
#
# where $n_c$ is the number of samples in class $c$ and $n=\sum_{c=1}^{K} n_c$.
#
# ### Interpretation
#
# Weighted F1 is more aligned with the natural production distribution than Macro F1.
#
# ## A.5.8 Macro Precision And Macro Recall
#
# The macro averages reported by `classification_report` are:
#
# $$
# \mathrm{MacroPrecision}=\frac{1}{K}\sum_{c=1}^{K}\mathrm{Precision}_c
# $$
#
# $$
# \mathrm{MacroRecall}=\frac{1}{K}\sum_{c=1}^{K}\mathrm{Recall}_c
# $$
#
# These give every class equal weight, regardless of how frequent that class is.
#
# ## A.5.9 Weighted Precision And Weighted Recall
#
# The weighted averages reported by `classification_report` are:
#
# $$
# \mathrm{WeightedPrecision}=\sum_{c=1}^{K}\frac{n_c}{n}\mathrm{Precision}_c
# $$
#
# $$
# \mathrm{WeightedRecall}=\sum_{c=1}^{K}\frac{n_c}{n}\mathrm{Recall}_c
# $$
#
# These weight each class by its observed frequency in the evaluation set.
#
# ## A.5.10 Repeated Mean Accuracy
#
# When evaluation is repeated across multiple splits, the reported mean accuracy is:
#
# $$
# \bar{A}=\frac{1}{m}\sum_{j=1}^{m} A_j
# $$
#
# where $A_j$ is the accuracy from split $j$ and $m$ is the number of repeated splits.
#
# ### Why It Is Used
#
# A single holdout split can be noisy. Repeated grouped evaluation gives a more stable estimate of expected performance.
#
# ## A.5.11 Accuracy Standard Deviation
#
# The standard deviation of repeated accuracies is:
#
# $$
# \sigma_A = \sqrt{\frac{1}{m}\sum_{j=1}^{m}(A_j-\bar{A})^2}
# $$
#
# ### Interpretation
#
# - lower standard deviation means more stable evaluation across splits
# - higher standard deviation means the score depends more on the particular split
#
# ## A.5.12 Train-Test Gap
#
# The train-test gap is:
#
# $$
# \mathrm{Gap}=\mathrm{TrainAccuracy}-\mathrm{ValidationAccuracy}
# $$
#
# ### Interpretation
#
# - small gap suggests better generalization
# - large gap suggests overfitting
# - in this project, the tuned grouped gap is around $0.0911$
#
# ## A.5.13 Balanced Unseen Accuracy
#
# Balanced unseen accuracy uses the same accuracy formula as holdout accuracy, but on a deliberately class-balanced evaluation set:
#
# $$
# \mathrm{BalancedAccuracyLikeHoldout}=\frac{1}{n}\sum_{i=1}^{n}\mathbf{1}(\hat{y}_i=y_i)
# $$
#
# The difference is not in the formula, but in the construction of the evaluation sample: each eligible class contributes the same number of unseen rows.
#
# ### Interpretation
#
# This is useful for judging rare-class robustness, but it should not replace the grouped natural-distribution score as the main business metric.
#
# ## A.5.14 Result Table Reading Guide
#
# A professional reading of the result table in this project is:
#
# - use grouped holdout accuracy as the primary business-facing estimate
# - use repeated grouped mean and standard deviation to judge stability
# - use macro metrics to judge rare-class behavior
# - use weighted metrics to judge natural-distribution behavior
# - use the train-validation gap to judge overfitting
# - use balanced unseen accuracy as a secondary stress test for class fairness

# %% [markdown]
# # Appendix B: Indexed Library Reference
#
# The definitions below are paraphrased from official project documentation and are included here to justify each library choice.
#
# ## B.1 pandas
#
# - **Documented definition**: pandas provides fast, flexible, and expressive data structures for working with labeled or relational data.
# - **Used in this project for**: JSON loading, missing-value cleanup, aggregation, and summary tables.
# - **Why justified**: this assignment is structured tabular text data, so dataframe operations are the cleanest and most readable way to perform EDA and reporting.
#
# ## B.2 NumPy
#
# - **Documented definition**: NumPy is the fundamental package for scientific computing in Python and provides multidimensional arrays plus numerical routines.
# - **Used in this project for**: vectorized labels, indexing, numerical summaries, and compatibility with scikit-learn.
# - **Why justified**: scikit-learn expects array-oriented inputs and outputs, so NumPy is the natural numerical base layer.
#
# ## B.3 Matplotlib
#
# - **Documented definition**: Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# - **Used in this project for**: histograms, bar charts, learning curves, validation curves, and summary plots.
# - **Why justified**: a report notebook needs reproducible professional charts, and Matplotlib is the standard plotting tool for that.
#
# ## B.4 scikit-learn
#
# - **Documented definition**: scikit-learn provides simple and efficient tools for predictive data analysis.
# - **Used in this project for**:
#   - TF-IDF vectorization
#   - one-hot encoding
#   - scaling
#   - grouped train/test splitting
#   - LinearSVC classification
#   - evaluation metrics and tuning
# - **Why justified**: this problem is a sparse multiclass text-classification problem, which is a strong fit for classical scikit-learn pipelines.
#
# ## B.5 joblib
#
# - **Documented definition**: joblib provides lightweight pipelining tools in Python and efficient persistence for large Python objects, especially those containing NumPy arrays.
# - **Used in this project for**: saving and loading the trained model artifact.
# - **Why justified**: model persistence is part of reproducibility, and joblib is a practical standard for classical ML pipelines.
#
# ## B.6 scipy.sparse.csr_matrix
#
# - **Documented definition**: CSR is a compressed sparse row matrix representation.
# - **Used in this project for**: storing high-dimensional sparse text features and scaled numeric features efficiently.
# - **Why justified**: TF-IDF matrices are mostly zeros, so dense storage is wasteful in both memory and compute.
# - **Mathematical intuition**: if a feature matrix $X \in \mathbb{R}^{n \times p}$ has mostly zero entries, sparse storage keeps only non-zero values and index locations rather than all $n \times p$ cells.
#
# ## B.7 sklearn.base.BaseEstimator
#
# - **Documented definition**: base class for estimators in scikit-learn.
# - **Used in this project for**: making custom transformers compatible with the scikit-learn estimator API.
# - **Why justified**: a consistent estimator interface is required for pipeline composition, fitting, parameter inspection, and validation.
#
# ## B.8 sklearn.base.TransformerMixin
#
# - **Documented definition**: mixin class for transformers in scikit-learn that provides a default \`fit_transform\` implementation.
# - **Used in this project for**: custom feature transformers that convert record dictionaries into model-ready sparse features.
# - **Why justified**: this keeps custom preprocessing aligned with native scikit-learn transformers.
#
# ## B.9 sklearn.feature_extraction.text.TfidfVectorizer
#
# - **Documented definition**: convert a collection of raw documents to a matrix of TF-IDF features.
# - **Used in this project for**: word-level and character-level sparse text features.
# - **Why justified**: item names and descriptions are the dominant predictive signal, and TF-IDF is a strong classical representation for sparse text classification.
# - **Mathematics**:
#
# $$
# \mathrm{tfidf}(t,d)=\mathrm{tf}(t,d)\cdot\mathrm{idf}(t)
# $$
#
# with
#
# $$
# \mathrm{idf}(t)=\log\left(\frac{N+1}{\mathrm{df}(t)+1}\right)+1
# $$
#
# ## B.10 sklearn.pipeline.FeatureUnion
#
# - **Documented definition**: concatenate results of multiple transformer objects.
# - **Used in this project for**: combining word TF-IDF, character TF-IDF, vendor encoding, and amount scaling into one feature matrix.
# - **Why justified**: the model needs text, categorical, and numeric signals together in a single aligned representation.
# - **Mathematical intuition**: if feature blocks are $X_1, X_2, \dots, X_m$, FeatureUnion forms a horizontal concatenation
#
# $$
# X = [X_1\; X_2\; \dots \; X_m]
# $$
#
# ## B.11 sklearn.preprocessing.MaxAbsScaler
#
# - **Documented definition**: scale each feature by its maximum absolute value.
# - **Used in this project for**: scaling the log-transformed amount feature without destroying sparsity.
# - **Why justified**: the amount feature should be numerically comparable without forcing dense centering.
# - **Mathematics**:
#
# $$
# x'_j = \frac{x_j}{\max_i |x_{ij}|}
# $$
#
# ## B.12 sklearn.preprocessing.OneHotEncoder
#
# - **Documented definition**: encode categorical features as a one-hot numeric array.
# - **Used in this project for**: converting vendor IDs into binary indicator columns.
# - **Why justified**: vendor identity is categorical, not ordinal, so one-hot encoding avoids imposing a false numerical relationship.
# - **Mathematical intuition**: for category set $\{c_1,\dots,c_K\}$, one-hot encoding maps category $c_k$ to vector $e_k \in \{0,1\}^K$ with one 1 and the rest 0.
#
# ## B.13 sklearn.pipeline.Pipeline
#
# - **Documented definition**: assemble several steps that can be cross-validated together while setting different parameters.
# - **Used in this project for**: connecting feature construction and LinearSVC into one trainable estimator.
# - **Why justified**: the training, evaluation, and persistence logic should operate on one consistent object.
#
# ## B.14 sklearn.metrics.accuracy_score
#
# - **Documented definition**: compute the classification accuracy score.
# - **Used in this project for**: headline performance measurement on holdout and repeated splits.
# - **Why justified**: the assignment sets an explicit accuracy threshold.
# - **Mathematics**:
#
# $$
# \mathrm{Accuracy}=\frac{1}{n}\sum_{i=1}^{n}\mathbf{1}(\hat{y}_i=y_i)
# $$
#
# ## B.15 sklearn.metrics.classification_report
#
# - **Documented definition**: build a text summary showing main classification metrics.
# - **Used in this project for**: per-class precision, recall, F1, macro averages, and weighted averages.
# - **Why justified**: a multiclass imbalanced problem needs more than a single scalar metric.
#
# ## B.16 sklearn.model_selection.GroupShuffleSplit
#
# - **Documented definition**: randomized train/test indices according to a third-party provided group.
# - **Used in this project for**: grouped holdout and grouped repeated evaluation by normalized item name.
# - **Why justified**: prevents repeated item-name templates from leaking across train and test.
#
# ## B.17 sklearn.model_selection.ShuffleSplit
#
# - **Documented definition**: randomized permutation cross-validator.
# - **Used in this project for**: quick random-row baseline comparison.
# - **Why justified**: useful as a naive benchmark, even though it is optimistic here.
#
# ## B.18 sklearn.model_selection.StratifiedGroupKFold
#
# - **Documented definition**: variation of K-fold that preserves class proportions as much as possible while respecting non-overlapping groups.
# - **Used in this project for**: feasibility checks on grouped stratified evaluation.
# - **Why justified**: helps test whether group-aware evaluation can also remain label-aware under severe imbalance.
#
# ## B.19 sklearn.model_selection.learning_curve
#
# - **Documented definition**: determine cross-validated training and test scores for different training set sizes.
# - **Used in this project for**: diagnosing whether more data would likely improve grouped validation accuracy.
# - **Why justified**: the train-validation gap alone does not show whether data scarcity is the main bottleneck.
#
# ## B.20 sklearn.model_selection.validation_curve
#
# - **Documented definition**: determine training and test scores for varying parameter values.
# - **Used in this project for**: studying how the SVM regularization parameter $C$ changes train and validation accuracy.
# - **Why justified**: necessary for bias-variance diagnosis and hyperparameter interpretation.
#
# ## B.21 sklearn.svm.LinearSVC
#
# - **Documented definition**: linear support vector classification implemented with liblinear.
# - **Used in this project for**: the final multiclass sparse-text classifier.
# - **Why justified**: linear SVMs are strong baselines for high-dimensional sparse text problems and are efficient enough for repeated grouped validation.
# - **Mathematics**: for class score $f_k(x)=w_k^T x+b_k$, prediction is
#
# $$
# \hat{y}=\arg\max_k f_k(x)
# $$
#
# and the optimization balances margin size against hinge-loss penalties through $C$.

# %% [markdown]
# # Appendix C: Indexed Concept Reference
#
# The concept definitions below are aligned with standard machine-learning documentation and glossary sources.
#
# ## C.1 Feature
#
# - **Definition**: an input variable used by a model.
# - **In this project**: text features, vendor identity, and log-scaled amount.
#
# ## C.2 Label
#
# - **Definition**: the answer or target portion of a supervised-learning example.
# - **In this project**: the label is `accountName`.
#
# ## C.3 Labeled Example
#
# - **Definition**: an example containing one or more features and a label.
# - **In this project**: one expense record with text, vendor, amount, and the true account label.
#
# ## C.4 Validation Set
#
# - **Definition**: the subset used for initial model evaluation during development.
# - **In this project**: grouped holdout and grouped CV act as validation mechanisms.
#
# ## C.5 Overfitting
#
# - **Definition**: a model performs well on training data but poorly on new unseen data.
# - **Observed here**: training accuracy is materially higher than grouped unseen accuracy.
#
# ## C.6 Underfitting
#
# - **Definition**: a model performs poorly on both training data and unseen data.
# - **Observed here**: not present, because both train and validation metrics are high.
#
# ## C.7 Class Imbalance
#
# - **Definition**: classes do not appear with roughly equal frequency.
# - **Why it matters here**: many account labels have very low support, so accuracy alone is not enough.
#
# ## C.8 Generalization
#
# - **Definition**: the ability of a model to perform well on new examples.
# - **Why it matters here**: the finance use case depends on unseen future transactions, not memorized templates.
#
# ## C.9 Bias-Variance Trade-off
#
# - **Bias**: error from an overly simple model.
# - **Variance**: error from excessive sensitivity to training details.
# - **Observed here**: variance is the main issue, not bias.

# %% [markdown]
# # Appendix D: Indexed Sample And Split Definitions
#
# ## D.1 Sample
#
# - **Definition**: a single row or observation in the dataset.
# - **In this notebook**: one expense record is one sample.
#
# ## D.2 Training Sample
#
# - **Definition**: a sample used to estimate model parameters.
#
# ## D.3 Validation Sample
#
# - **Definition**: a held-out sample used to estimate generalization during development.
#
# ## D.4 Balanced Unseen Sample
#
# - **Definition**: a held-out sample constructed so that eligible labels contribute equally many examples.
# - **Purpose**: stress-test minority-class performance without changing the real production distribution.
#
# ## D.5 Eligible Label
#
# - **Definition**: a label with enough rows and enough distinct normalized item-name groups to support balanced unseen evaluation.
#
# ## D.6 Support
#
# - **Definition**: the number of evaluated samples belonging to a class.
#
# ## D.7 Leakage
#
# - **Definition**: information from training data reaches evaluation data in a way that inflates the metric.
# - **In this project**: repeated normalized item names can leak phrase templates across random row splits.

# %% [markdown]
# # Appendix E: Source Notes And Index
#
# ## E.1 Documentation Basis
#
# The appendix definitions above are paraphrased from official documentation and glossary pages for:
#
# 1. pandas documentation
# 2. NumPy documentation
# 3. Matplotlib documentation
# 4. scikit-learn documentation
# 5. joblib documentation
# 6. Google Machine Learning glossary / crash course
#
# ## E.2 Index
#
# | Index | Topic |
# | --- | --- |
# | A | Mathematical notes and equations |
# | B | Machine-learning and Python library definitions |
# | C | Core ML concept definitions |
# | D | Sample and split terminology |
# | E | Source notes and index |
#
# ## E.3 Usage Justification Summary
#
# - pandas: best fit for labeled tabular data loading and summarization
# - NumPy: numerical base layer for arrays and vectorized operations
# - Matplotlib: reproducible report-quality charts
# - scikit-learn: efficient classical ML pipeline for sparse text classification
# - joblib: lightweight persistence for trained artifacts
